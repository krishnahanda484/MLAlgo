# %% [markdown]
# LOGISTIC REGRESSION

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\conte\Downloads\placement.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  100 non-null    int64
#  1   cgpa        100 non-null    float64
#  2   iq          100 non-null    float64
#  3   placement   100 non-null    int64
# dtypes: float64(2), int64(2)
# memory usage: 3.3 KB

# %%
df.shape
# Out:
# (100, 4)

# %%
df = df.iloc[:,1:]

# %%
df.head()
# Out:
#    cgpa     iq  placement
# 0   6.8  123.0          1
# 1   5.9  106.0          0
# 2   5.3  121.0          0
# 3   7.4  132.0          1
# 4   5.8  142.0          0

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['cgpa'],df['iq'],c=df['placement'])

# %%
X = df.iloc[:,0:2]
y = df.iloc[:,-1]

# %%
X
# Out:
#     cgpa     iq
# 0    6.8  123.0
# 1    5.9  106.0
# 2    5.3  121.0
# 3    7.4  132.0
# 4    5.8  142.0
# ..   ...    ...
# 95   4.3  200.0
# 96   4.4   42.0
# 97   6.7  182.0
# 98   6.3  103.0
# 99   6.2  113.0
#
# [100 rows x 2 columns]

# %%
y
# Out:
# 0     1
# 1     0
# 2     0
# 3     1
# 4     0
#      ..
# 95    0
# 96    0
# 97    1
# 98    1
# 99    1
# Name: placement, Length: 100, dtype: int64

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1)

# %%
X_train
# Out:
#     cgpa     iq
# 44   7.5   61.0
# 73   4.9   61.0
# 59   4.8  112.0
# 60   6.9  139.0
# 76   4.9  155.0
# ..   ...    ...
# 81   5.4  107.0
# 32   7.0  139.0
# 37   8.1  149.0
# 75   4.8  169.0
# 21   7.1  151.0
#
# [90 rows x 2 columns]

# %%
X_test
# Out:
#     cgpa     iq
# 51   4.8  141.0
# 69   8.5  120.0
# 3    7.4  132.0
# 54   6.4  141.0
# 79   6.5   90.0
# 70   6.3  127.0
# 98   6.3  103.0
# 87   5.7  132.0
# 23   4.7   87.0
# 26   7.0  199.0

# %%
y_train
# Out:
# 44    1
# 73    0
# 59    0
# 60    1
# 76    0
#      ..
# 81    0
# 32    1
# 37    1
# 75    0
# 21    1
# Name: placement, Length: 90, dtype: int64

# %%
y_test
# Out:
# 51    0
# 69    1
# 3     1
# 54    1
# 79    1
# 70    1
# 98    1
# 87    1
# 23    0
# 26    1
# Name: placement, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
X_train = scaler.fit_transform(X_train)

# %%
X_train
# Out:
# array([[ 1.3638475 , -1.53023118],
#        [-0.92389669, -1.53023118],
#        [-1.01188685, -0.2750916 ],
#        [ 0.83590653,  0.38939407],
#        [-0.92389669,  0.78316335],
#        [-0.74791637, -1.40717828],
#        [-0.65992621,  2.48129338],
#        [-0.92389669,  0.26634117],
#        [ 0.48394589,  0.90621625],
#        [ 0.92389669,  1.27537495],
#        [-0.65992621, -0.81652436],
#        [-0.2199754 ,  0.48783639],
#        [ 0.65992621,  1.44764902],
#        [-1.18786718,  0.56166813],
#        [ 0.92389669, -1.45639944],
#        [ 0.13198524,  0.80777393],
#        [-0.13198524,  0.46322581],
#        [-0.83590653, -0.12742812],
#        [ 0.74791637, -0.81652436],
#        [ 1.3638475 ,  0.85699509],
#        [ 0.04399508, -0.5211974 ],
#        [-0.13198524,  1.05387973],
#        [ 1.89178847,  1.05387973],
#        [-2.15575895,  2.7027886 ],
#        [ 1.45183766, -0.84113494],
#        [-0.57193605, -0.22587044],
#        [-0.92389669, -0.07820695],
#        [ 0.13198524, -0.49658682],
#        [ 1.18786718, -0.91496668],
#        [ 0.48394589, -2.12088511],
#        [-0.48394589,  0.29095175],
#        [ 0.39595573, -0.17664928],
#        [ 1.45183766,  0.11867769],
#        [ 0.04399508, -1.92400047],
#        [ 1.80379831, -1.08724074],
#        [ 0.2199754 , -0.25048102],
#        [-0.65992621, -0.32431276],
#        [ 0.83590653, -0.66886088],
#        [ 1.62781798, -0.22587044],
#        [-0.65992621,  0.93082683],
#        [ 0.13198524, -1.43178886],
#        [-0.48394589, -0.22587044],
#        [-0.74791637,  1.29998553],
#        [ 0.74791637, -0.00437521],
#        [-0.92389669,  1.79219714],
#        [-0.83590653, -0.79191378],
#        [-1.3638475 , -1.99783221],
#        [-0.2199754 ,  1.12771147],
#        [ 0.83590653,  0.36478349],
#        [ 1.18786718, -1.80094757],
#        [ 1.18786718, -0.17664928],
#        [ 0.04399508,  0.63549987],
#        [ 1.18786718,  0.34017291],
#        [ 2.06776879,  1.10310089],
#        [-0.2199754 ,  0.41400465],
#        [-0.57193605, -0.05359637],
#        [-2.33173927,  1.4722596 ],
#        [-1.71580815, -0.57041856],
#        [ 1.3638475 ,  0.16789885],
#        [ 0.04399508, -1.40717828],
#        [ 0.74791637, -0.2750916 ],
#        [ 0.13198524, -1.03801958],
#        [ 0.04399508,  0.02023537],
#        [ 0.57193605, -0.07820695],
#        [-1.09987702, -1.75172641],
#        [ 0.13198524,  0.21712001],
#        [ 0.30796556,  0.11867769],
#        [-0.65992621,  0.21712001],
#        [-1.71580815, -1.18568306],
#        [-0.48394589,  0.38939407],
#        [-1.80379831, -0.34892334],
#        [-0.83590653, -1.48101002],
#        [ 1.01188685, -1.85016873],
#        [ 0.48394589,  0.16789885],
#        [-0.04399508, -0.42275508],
#        [-1.45183766,  1.89063946],
#        [ 0.74791637,  0.43861523],
#        [-1.3638475 ,  0.63549987],
#        [-0.74791637,  0.11867769],
#        [ 0.92389669, -0.2750916 ],
#        [-1.09987702, -0.05359637],
#        [ 0.65992621,  0.75855277],
#        [ 0.57193605,  0.36478349],
#        [-0.92389669,  0.68472103],
#        [-1.01188685,  0.98004799],
#        [-0.48394589, -0.3981445 ],
#        [ 0.92389669,  0.38939407],
#        [ 1.89178847,  0.63549987],
#        [-1.01188685,  1.12771147],
#        [ 1.01188685,  0.68472103]])

# %%
X_test = scaler.transform(X_test)

# %%
X_test
# Out:
# array([[-1.01188685,  0.43861523],
#        [ 2.24374911, -0.07820695],
#        [ 1.27585734,  0.21712001],
#        [ 0.39595573,  0.43861523],
#        [ 0.48394589, -0.81652436],
#        [ 0.30796556,  0.09406711],
#        [ 0.30796556, -0.49658682],
#        [-0.2199754 ,  0.21712001],
#        [-1.09987702, -0.8903561 ],
#        [ 0.92389669,  1.86602888]])

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf = LogisticRegression()

# %%
#model training
clf.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred = clf.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)*100
# Out:
# 90.0

# %%
pip install mlxtend
# Out:
# Collecting mlxtend
#   Downloading mlxtend-0.23.4-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: scipy>=1.2.1 in c:\users\conte\anaconda3\lib\site-packages (from mlxtend) (1.15.3)
# Requirement already satisfied: numpy>=1.16.2 in c:\users\conte\anaconda3\lib\site-packages (from mlxtend) (2.1.3)
# Requirement already satisfied: pandas>=0.24.2 in c:\users\conte\anaconda3\lib\site-packages (from mlxtend) (2.2.3)
# Requirement already satisfied: scikit-learn>=1.3.1 in c:\users\conte\anaconda3\lib\site-packages (from mlxtend) (1.6.1)
# Requirement already satisfied: matplotlib>=3.0.0 in c:\users\conte\anaconda3\lib\site-packages (from mlxtend) (3.10.0)
# Requirement already satisfied: joblib>=0.13.2 in c:\users\conte\anaconda3\lib\site-packages (from mlxtend) (1.4.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\conte\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\conte\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\conte\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\conte\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\conte\appdata\roaming\python\python313\site-packages (from matplotlib>=3.0.0->mlxtend) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\conte\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\conte\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\conte\appdata\roaming\python\python313\site-packages (from matplotlib>=3.0.0->mlxtend) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\conte\anaconda3\lib\site-packages (from pandas>=0.24.2->mlxtend) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\conte\appdata\roaming\python\python313\site-packages (from pandas>=0.24.2->mlxtend) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\conte\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.17.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\conte\anaconda3\lib\site-packages (from scikit-learn>=1.3.1->mlxtend) (3.5.0)
# Downloading mlxtend-0.23.4-py3-none-any.whl (1.4 MB)
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    --------------- ------------------------ 0.5/1.4 MB 2.7 MB/s eta 0:00:01
#    ------------------------------- -------- 1.0/1.4 MB 2.6 MB/s eta 0:00:01
#    ---------------------------------------- 1.4/1.4 MB 2.6 MB/s  0:00:00
# Installing collected packages: mlxtend
# Successfully installed mlxtend-0.23.4
# Note: you may need to restart the kernel to use updated packages.

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(X_train,y_train.values,clf=clf,legend=2)
# Out:
# <Axes: >

# %%
import pickle

# %%
pickle.dump(clf,open('model.pkl','wb'))
